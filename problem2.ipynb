# %%
import matplotlib.pyplot as plt

# %%
def nr_of_grains(days):
    total = 1
    amounts = []
    amounts.append(total)
    
    for i in range(0, days):
        total = 2 * total
        amounts.append(total)

    return amounts

# %%
days = int(input('Insert the number of days: '))
amounts = nr_of_grains(days)

# %%
print(f'the amount of grains after {days} days is {amounts[-1]}')
# Out:
# the amount of grains after 100 days is 1267650600228229401496703205376

# %%
plt.title('Number of grains of rice on the 100th day')
# Out:
# Text(0.5, 1.0, 'Number of grains of rice on the 100th day')

# %%
plt.xlabel('Days')
plt.ylabel('Nr of grains')
# Out:
# Text(0, 0.5, 'Nr of grains')

# %%
plt.plot(amounts, color='black', marker='o', linewidth=2, markersize=5, markerfacecolor='blue')
